# %%
import pandas as pd
dataset = pd.read_csv("business-price-indexes-september-2022-quarter-csv.csv")
dataset.head()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6976\1430485683.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv("business-price-indexes-september-2022-quarter-csv.csv")
#   Series_reference   Period  Data_value STATUS  UNITS  \
# 0       CEPQ.S2371  1996.12       899.0  FINAL  Index
# 1       CEPQ.S2371  1997.03       884.0  FINAL  Index
# 2       CEPQ.S2371  1997.06       925.0  FINAL  Index
# 3       CEPQ.S2371  1997.09       932.0  FINAL  Index
# 4       CEPQ.S2371  1997.12       929.0  FINAL  Index
#
#                            Subject  \
# 0  Capital Goods Price Index - CEP
# 1  Capital Goods Price Index - CEP
# 2  Capital Goods Price Index - CEP
# 3  Capital Goods Price Index - CEP
# 4  Capital Goods Price Index - CEP
#
#                                                Group  \
# 0  Price Index by Item - Plant, Machinery and Equ...
# 1  Price Index by Item - Plant, Machinery and Equ...
# ...

# %%
dataset.describe()
# Out:
#              Period    Data_value  Series_title_3  Series_title_4  \
# count  74306.000000  73906.000000             0.0             0.0
# mean    2008.168311    964.375042             NaN             NaN
# std        9.809260    314.784042             NaN             NaN
# min     1977.120000     -5.800000             NaN             NaN
# 25%     2001.030000    778.603261             NaN             NaN
# 50%     2010.060000    998.000000             NaN             NaN
# 75%     2016.120000   1106.000000             NaN             NaN
# max     2022.090000   5239.000000             NaN             NaN
#
#        Series_title_5
# count             0.0
# mean              NaN
# std               NaN
# min               NaN
# 25%               NaN
# 50%               NaN
# 75%               NaN
# max               NaN

# %%
dataset.iloc[1:5,1:5]
# Out:
#     Period  Data_value STATUS  UNITS
# 1  1997.03       884.0  FINAL  Index
# 2  1997.06       925.0  FINAL  Index
# 3  1997.09       932.0  FINAL  Index
# 4  1997.12       929.0  FINAL  Index

# %%
dataset.head()
# Out:
#   Series_reference   Period  Data_value STATUS  UNITS  \
# 0       CEPQ.S2371  1996.12       899.0  FINAL  Index
# 1       CEPQ.S2371  1997.03       884.0  FINAL  Index
# 2       CEPQ.S2371  1997.06       925.0  FINAL  Index
# 3       CEPQ.S2371  1997.09       932.0  FINAL  Index
# 4       CEPQ.S2371  1997.12       929.0  FINAL  Index
#
#                            Subject  \
# 0  Capital Goods Price Index - CEP
# 1  Capital Goods Price Index - CEP
# 2  Capital Goods Price Index - CEP
# 3  Capital Goods Price Index - CEP
# 4  Capital Goods Price Index - CEP
#
#                                                Group  \
# 0  Price Index by Item - Plant, Machinery and Equ...
# 1  Price Index by Item - Plant, Machinery and Equ...
# 2  Price Index by Item - Plant, Machinery and Equ...
# 3  Price Index by Item - Plant, Machinery and Equ...
# 4  Price Index by Item - Plant, Machinery and Equ...
#
#              Series_title_1 Series_title_2  Series_title_3  Series_title_4  \
# ...

# %%
dataset.drop('Series_title_2',axis = 1)
# Out:
#       Series_reference   Period  Data_value STATUS  UNITS  \
# 0           CEPQ.S2371  1996.12       899.0  FINAL  Index
# 1           CEPQ.S2371  1997.03       884.0  FINAL  Index
# 2           CEPQ.S2371  1997.06       925.0  FINAL  Index
# 3           CEPQ.S2371  1997.09       932.0  FINAL  Index
# 4           CEPQ.S2371  1997.12       929.0  FINAL  Index
# ...                ...      ...         ...    ...    ...
# 74301   PPIQ.SQURS2110  2021.09      1328.0  FINAL  Index
# 74302   PPIQ.SQURS2110  2021.12      1342.0  FINAL  Index
# 74303   PPIQ.SQURS2110  2022.03      1391.0  FINAL  Index
# 74304   PPIQ.SQURS2110  2022.06      1432.0  FINAL  Index
# 74305   PPIQ.SQURS2110  2022.09      1459.0  FINAL  Index
#
#                                Subject  \
# 0      Capital Goods Price Index - CEP
# 1      Capital Goods Price Index - CEP
# 2      Capital Goods Price Index - CEP
# 3      Capital Goods Price Index - CEP
# 4      Capital Goods Price Index - CEP
# ...

# %%
dataset.head()
def put(put):
    return 4
dataset[['Series_title_3']].apply(put)
# Out:
# Series_title_3    4
# dtype: int64

# %%
dataset['Series_title_1'].value_counts()
# Out:
# All Industries                                                1070
# Mining                                                         684
# Owner-Occupied Property Operation (National Accounts Only)     684
# Printing                                                       684
# Wholesale Trade                                                684
#                                                               ...
# Sheep, beef, and grain farms - Fertiliser, lime and seeds       36
# Sheep, beef, and grain farms - Freight                          36
# Sheep, beef, and grain farms - Fuel                             36
# Sheep, beef, and grain farms - Insurance premiums               36
# Poultry, deer, and other livestock - Seeds                      36
# Name: Series_title_1, Length: 471, dtype: int64
